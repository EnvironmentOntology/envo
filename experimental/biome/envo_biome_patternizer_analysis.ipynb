# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pl
import upsetplot as usp

# %%
# this is generated by patternizer; see Makefile for details
df = pd.read_csv("biome_lexical.tsv", sep="\t").fillna("")

# %%
df[0:5]
# Out:
#         x_tokens    biome_class  biome_class label        x_class  \
# 0                 ENVO:01000029  marine reef biome  ENVO:01000143
# 1  littoral|zone  ENVO:00000873   freshwater biome  ENVO:01000409
# 2           lake  ENVO:00000873   freshwater biome  ENVO:00000021
# 3          marsh  ENVO:00000873   freshwater biome  ENVO:00000053
# 4          river  ENVO:00000873   freshwater biome  ENVO:01000297
#
#               x_class label biome_pred x_pred rels biome_category  \
# 0               marine reef      label  label           ecosystem
# 1  freshwater littoral zone      label  label           ecosystem
# 2           freshwater lake      label  label           ecosystem
# 3          freshwater marsh      label  label           ecosystem
# 4          freshwater river      label  label           ecosystem
#
#                x_category
# 0  astronomical body part
# 1      environmental zone
# 2  astronomical body part
# 3               ecosystem
# 4  astronomical body part

# %%
fdf = df.loc[df['x_tokens'].isin(['', 'ecosystem'])]
fdf[0:5]
# Out:
#     x_tokens    biome_class  biome_class label        x_class x_class label  \
# 0             ENVO:01000029  marine reef biome  ENVO:01000143   marine reef
# 103           ENVO:00000873   freshwater biome  ENVO:00002011   fresh water
# 105           ENVO:00000873   freshwater biome  ENVO:00002011   fresh water
# 108           ENVO:00000873   freshwater biome  ENVO:00002011   fresh water
# 112           ENVO:00000873   freshwater biome  ENVO:00002011   fresh water
#
#     biome_pred x_pred rels biome_category              x_category
# 0        label  label           ecosystem  astronomical body part
# 103      label  exact           ecosystem  environmental material
# 105      label  exact           ecosystem  environmental material
# 108      label  exact           ecosystem  environmental material
# 112      label  exact           ecosystem  environmental material

# %%
fdf.loc[df['rels'] != ""]
# Out:
#        x_tokens    biome_class    biome_class label        x_class  \
# 178              ENVO:01000339          polar biome  ENVO:01000238
# 185              ENVO:01000339          polar biome  ENVO:01000238
# 188              ENVO:01000339          polar biome  ENVO:01000238
# 191              ENVO:01000339          polar biome  ENVO:01000238
# 195              ENVO:01000339          polar biome  ENVO:01000238
# 200              ENVO:01000339          polar biome  ENVO:01000238
# 205              ENVO:01000339          polar biome  ENVO:01000238
# 210              ENVO:01000339          polar biome  ENVO:01000238
# 216   ecosystem  ENVO:01000245       cropland biome  ENVO:01001244
# 219              ENVO:01000179         desert biome  ENVO:01001357
# 250              ENVO:01000179         desert biome  ENVO:01001357
# 252              ENVO:01000179         desert biome  ENVO:01001357
# 266              ENVO:01000179         desert biome  ENVO:01001357
# 268              ENVO:01000179         desert biome  ENVO:01001357
# 321   ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 323   ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 330   ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 334   ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 337   ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 345   ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 350   ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 361   ecosystem  ENVO:01000177      grassland biome  ENVO:01001206
# 364   ecosystem  ENVO:01000177      grassland biome  ENVO:01001206
# 367   ecosystem  ENVO:01000177      grassland biome  ENVO:01001206
# 370   ecosystem  ENVO:01000177      grassland biome  ENVO:01001206
# 373              ENVO:01000177      grassland biome  ENVO:01001206
# 416   ecosystem  ENVO:01001505  alpine tundra biome  ENVO:01001371
# 417              ENVO:01000180         tundra biome  ENVO:00000112
# 418   ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# 422   ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# ...         ...            ...                  ...            ...
# 3044  ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 3051  ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 3055  ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 3058  ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 3066  ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 3071  ecosystem  ENVO:01000174         forest biome  ENVO:01001243
# 3103  ecosystem  ENVO:01000177      grassland biome  ENVO:01001206
# 3106  ecosystem  ENVO:01000177      grassland biome  ENVO:01001206
# 3109  ecosystem  ENVO:01000177      grassland biome  ENVO:01001206
# 3112  ecosystem  ENVO:01000177      grassland biome  ENVO:01001206
# 3115             ENVO:01000177      grassland biome  ENVO:01001206
# 3125             ENVO:01000179         desert biome  ENVO:01001357
# 3156             ENVO:01000179         desert biome  ENVO:01001357
# 3158             ENVO:01000179         desert biome  ENVO:01001357
# 3172             ENVO:01000179         desert biome  ENVO:01001357
# 3174             ENVO:01000179         desert biome  ENVO:01001357
# 3225             ENVO:01000180         tundra biome  ENVO:00000112
# 3226  ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# 3230  ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# 3231             ENVO:01000180         tundra biome  ENVO:00000112
# 3232  ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# 3233             ENVO:01000180         tundra biome  ENVO:00000112
# 3236  ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# 3237             ENVO:01000180         tundra biome  ENVO:00000112
# 3240  ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# 3241             ENVO:01000180         tundra biome  ENVO:00000112
# 3244  ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# 3245             ENVO:01000180         tundra biome  ENVO:00000112
# 3248  ecosystem  ENVO:01000180         tundra biome  ENVO:01001370
# 3249             ENVO:01000180         tundra biome  ENVO:00000112
#
#                 x_class label biome_pred x_pred  \
# 178                     polar      label  label
# 185                     polar      label  label
# 188                     polar      label  label
# 191                     polar      label  label
# 195                     polar      label  label
# 200                     polar      label  label
# 205                     polar      label  label
# 210                     polar      label  label
# 216        cropland ecosystem      label  label
# 219                    desert      label  label
# 250                    desert      label  label
# 252                    desert      label  label
# 266                    desert      label  label
# 268                    desert      label  label
# 321          forest ecosystem      label  label
# 323          forest ecosystem      label  label
# 330          forest ecosystem      label  label
# 334          forest ecosystem      label  label
# 337          forest ecosystem      label  label
# 345          forest ecosystem      label  label
# 350          forest ecosystem      label  label
# 361       grassland ecosystem      label  label
# 364       grassland ecosystem      label  label
# 367       grassland ecosystem      label  label
# 370       grassland ecosystem      label  label
# 373       grassland ecosystem      label  exact
# 416   alpine tundra ecosystem      label  label
# 417                    tundra      label  label
# 418          tundra ecosystem      label  label
# 422          tundra ecosystem      label  label
# ...                       ...        ...    ...
# 3044         forest ecosystem      label  label
# 3051         forest ecosystem      label  label
# 3055         forest ecosystem      label  label
# 3058         forest ecosystem      label  label
# 3066         forest ecosystem      label  label
# 3071         forest ecosystem      label  label
# 3103      grassland ecosystem      label  label
# 3106      grassland ecosystem      label  label
# 3109      grassland ecosystem      label  label
# 3112      grassland ecosystem      label  label
# 3115      grassland ecosystem      label  exact
# 3125                   desert      label  label
# 3156                   desert      label  label
# 3158                   desert      label  label
# 3172                   desert      label  label
# 3174                   desert      label  label
# 3225                   tundra      label  label
# 3226         tundra ecosystem      label  label
# 3230         tundra ecosystem      label  label
# 3231                   tundra      label  label
# 3232         tundra ecosystem      label  label
# 3233                   tundra      label  label
# 3236         tundra ecosystem      label  label
# 3237                   tundra      label  label
# 3240         tundra ecosystem      label  label
# 3241                   tundra      label  label
# 3244         tundra ecosystem      label  label
# 3245                   tundra      label  label
# 3248         tundra ecosystem      label  label
# 3249                   tundra      label  label
#
#                                                    rels biome_category  \
# 178           http://purl.obolibrary.org/obo/RO_0000086      ecosystem
# 185           http://purl.obolibrary.org/obo/RO_0000086      ecosystem
# 188           http://purl.obolibrary.org/obo/RO_0000086      ecosystem
# 191           http://purl.obolibrary.org/obo/RO_0000086      ecosystem
# 195           http://purl.obolibrary.org/obo/RO_0000086      ecosystem
# 200           http://purl.obolibrary.org/obo/RO_0000086      ecosystem
# 205           http://purl.obolibrary.org/obo/RO_0000086      ecosystem
# 210           http://purl.obolibrary.org/obo/RO_0000086      ecosystem
# 216           http://purl.obolibrary.org/obo/RO_0002473      ecosystem
# 219   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 250   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 252   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 266   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 268   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 321          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 323          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 330          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 334          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 337          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 345          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 350          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 361   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 364   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 367   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 370   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 373   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 416   common(http://purl.obolibrary.org/obo/ENVO_010...      ecosystem
# 417   http://purl.obolibrary.org/obo/RO_0002131|reve...      ecosystem
# 418   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 422   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# ...                                                 ...            ...
# 3044         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3051         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3055         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3058         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3066         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3071         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3103  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3106  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3109  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3112  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3115  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3125  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3156  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3158  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3172  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3174  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3225  http://purl.obolibrary.org/obo/RO_0002131|reve...      ecosystem
# 3226  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3230  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3231  http://purl.obolibrary.org/obo/RO_0002131|reve...      ecosystem
# 3232  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3233  http://purl.obolibrary.org/obo/RO_0002131|reve...      ecosystem
# 3236  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3237  http://purl.obolibrary.org/obo/RO_0002131|reve...      ecosystem
# 3240  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3241  http://purl.obolibrary.org/obo/RO_0002131|reve...      ecosystem
# 3244  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3245  http://purl.obolibrary.org/obo/RO_0002131|reve...      ecosystem
# 3248  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3249  http://purl.obolibrary.org/obo/RO_0002131|reve...      ecosystem
#
#                   x_category
# 178
# 185
# 188
# 191
# 195
# 200
# 205
# 210
# 216                ecosystem
# 219   astronomical body part
# 250   astronomical body part
# 252   astronomical body part
# 266   astronomical body part
# 268   astronomical body part
# 321                ecosystem
# 323                ecosystem
# 330                ecosystem
# 334                ecosystem
# 337                ecosystem
# 345                ecosystem
# 350                ecosystem
# 361                ecosystem
# 364                ecosystem
# 367                ecosystem
# 370                ecosystem
# 373                ecosystem
# 416                ecosystem
# 417       environmental zone
# 418                ecosystem
# 422                ecosystem
# ...                      ...
# 3044               ecosystem
# 3051               ecosystem
# 3055               ecosystem
# 3058               ecosystem
# 3066               ecosystem
# 3071               ecosystem
# 3103               ecosystem
# 3106               ecosystem
# 3109               ecosystem
# 3112               ecosystem
# 3115               ecosystem
# 3125  astronomical body part
# 3156  astronomical body part
# 3158  astronomical body part
# 3172  astronomical body part
# 3174  astronomical body part
# 3225      environmental zone
# 3226               ecosystem
# 3230               ecosystem
# 3231      environmental zone
# 3232               ecosystem
# 3233      environmental zone
# 3236               ecosystem
# 3237      environmental zone
# 3240               ecosystem
# 3241      environmental zone
# 3244               ecosystem
# 3245      environmental zone
# 3248               ecosystem
# 3249      environmental zone
#
# [210 rows x 10 columns]

# %%
fdf.loc[fdf['x_category'] == 'ecosystem']
# Out:
#        x_tokens    biome_class        biome_class label        x_class  \
# 214              ENVO:01000197   broadleaf forest biome  ENVO:01000430
# 215              ENVO:01000196  coniferous forest biome  ENVO:01000433
# 216   ecosystem  ENVO:01000245           cropland biome  ENVO:01001244
# 321   ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 323   ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 330   ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 334   ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 337   ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 345   ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 350   ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 361   ecosystem  ENVO:01000177          grassland biome  ENVO:01001206
# 364   ecosystem  ENVO:01000177          grassland biome  ENVO:01001206
# 367   ecosystem  ENVO:01000177          grassland biome  ENVO:01001206
# 370   ecosystem  ENVO:01000177          grassland biome  ENVO:01001206
# 373              ENVO:01000177          grassland biome  ENVO:01001206
# 407              ENVO:01000198       mixed forest biome  ENVO:01000431
# 416   ecosystem  ENVO:01001505      alpine tundra biome  ENVO:01001371
# 418   ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 422   ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 424   ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 428   ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 432   ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 436   ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 440   ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 444   ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 446   ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 456   ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 458   ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 461   ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 2282  ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# ...         ...            ...                      ...            ...
# 2524             ENVO:01000198       mixed forest biome  ENVO:01000431
# 2525  ecosystem  ENVO:01000245           cropland biome  ENVO:01001244
# 2548  ecosystem  ENVO:01001505      alpine tundra biome  ENVO:01001371
# 3042  ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 3044  ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 3051  ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 3055  ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 3058  ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 3066  ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 3071  ecosystem  ENVO:01000174             forest biome  ENVO:01001243
# 3081  ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 3083  ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 3093  ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 3095  ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 3098  ecosystem  ENVO:01000175           woodland biome  ENVO:01001245
# 3103  ecosystem  ENVO:01000177          grassland biome  ENVO:01001206
# 3106  ecosystem  ENVO:01000177          grassland biome  ENVO:01001206
# 3109  ecosystem  ENVO:01000177          grassland biome  ENVO:01001206
# 3112  ecosystem  ENVO:01000177          grassland biome  ENVO:01001206
# 3115             ENVO:01000177          grassland biome  ENVO:01001206
# 3226  ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 3230  ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 3232  ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 3236  ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 3240  ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 3244  ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 3248  ecosystem  ENVO:01000180             tundra biome  ENVO:01001370
# 3282             ENVO:01000196  coniferous forest biome  ENVO:01000433
# 3283             ENVO:01000197   broadleaf forest biome  ENVO:01000430
# 3284             ENVO:01000198       mixed forest biome  ENVO:01000431
#
#                 x_class label biome_pred x_pred  \
# 214          broadleaf forest      label  label
# 215         needleleaf forest      label  exact
# 216        cropland ecosystem      label  label
# 321          forest ecosystem      label  label
# 323          forest ecosystem      label  label
# 330          forest ecosystem      label  label
# 334          forest ecosystem      label  label
# 337          forest ecosystem      label  label
# 345          forest ecosystem      label  label
# 350          forest ecosystem      label  label
# 361       grassland ecosystem      label  label
# 364       grassland ecosystem      label  label
# 367       grassland ecosystem      label  label
# 370       grassland ecosystem      label  label
# 373       grassland ecosystem      label  exact
# 407              mixed forest      label  label
# 416   alpine tundra ecosystem      label  label
# 418          tundra ecosystem      label  label
# 422          tundra ecosystem      label  label
# 424          tundra ecosystem      label  label
# 428          tundra ecosystem      label  label
# 432          tundra ecosystem      label  label
# 436          tundra ecosystem      label  label
# 440          tundra ecosystem      label  label
# 444        woodland ecosystem      label  label
# 446        woodland ecosystem      label  label
# 456        woodland ecosystem      label  label
# 458        woodland ecosystem      label  label
# 461        woodland ecosystem      label  label
# 2282         forest ecosystem      label  label
# ...                       ...        ...    ...
# 2524             mixed forest      label  label
# 2525       cropland ecosystem      label  label
# 2548  alpine tundra ecosystem      label  label
# 3042         forest ecosystem      label  label
# 3044         forest ecosystem      label  label
# 3051         forest ecosystem      label  label
# 3055         forest ecosystem      label  label
# 3058         forest ecosystem      label  label
# 3066         forest ecosystem      label  label
# 3071         forest ecosystem      label  label
# 3081       woodland ecosystem      label  label
# 3083       woodland ecosystem      label  label
# 3093       woodland ecosystem      label  label
# 3095       woodland ecosystem      label  label
# 3098       woodland ecosystem      label  label
# 3103      grassland ecosystem      label  label
# 3106      grassland ecosystem      label  label
# 3109      grassland ecosystem      label  label
# 3112      grassland ecosystem      label  label
# 3115      grassland ecosystem      label  exact
# 3226         tundra ecosystem      label  label
# 3230         tundra ecosystem      label  label
# 3232         tundra ecosystem      label  label
# 3236         tundra ecosystem      label  label
# 3240         tundra ecosystem      label  label
# 3244         tundra ecosystem      label  label
# 3248         tundra ecosystem      label  label
# 3282        needleleaf forest      label  exact
# 3283         broadleaf forest      label  label
# 3284             mixed forest      label  label
#
#                                                    rels biome_category  \
# 214                                                          ecosystem
# 215                                                          ecosystem
# 216           http://purl.obolibrary.org/obo/RO_0002473      ecosystem
# 321          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 323          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 330          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 334          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 337          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 345          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 350          http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 361   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 364   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 367   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 370   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 373   reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 407                                                          ecosystem
# 416   common(http://purl.obolibrary.org/obo/ENVO_010...      ecosystem
# 418   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 422   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 424   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 428   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 432   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 436   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 440   common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 444                                                          ecosystem
# 446                                                          ecosystem
# 456                                                          ecosystem
# 458                                                          ecosystem
# 461                                                          ecosystem
# 2282         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# ...                                                 ...            ...
# 2524                                                         ecosystem
# 2525          http://purl.obolibrary.org/obo/RO_0002473      ecosystem
# 2548  common(http://purl.obolibrary.org/obo/ENVO_010...      ecosystem
# 3042         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3044         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3051         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3055         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3058         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3066         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3071         http://purl.obolibrary.org/obo/BFO_0000051      ecosystem
# 3081                                                         ecosystem
# 3083                                                         ecosystem
# 3093                                                         ecosystem
# 3095                                                         ecosystem
# 3098                                                         ecosystem
# 3103  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3106  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3109  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3112  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3115  reverse(http://purl.obolibrary.org/obo/BFO_000...      ecosystem
# 3226  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3230  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3232  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3236  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3240  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3244  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3248  common(http://purl.obolibrary.org/obo/ENVO_000...      ecosystem
# 3282                                                         ecosystem
# 3283                                                         ecosystem
# 3284                                                         ecosystem
#
#      x_category
# 214   ecosystem
# 215   ecosystem
# 216   ecosystem
# 321   ecosystem
# 323   ecosystem
# 330   ecosystem
# 334   ecosystem
# 337   ecosystem
# 345   ecosystem
# 350   ecosystem
# 361   ecosystem
# 364   ecosystem
# 367   ecosystem
# 370   ecosystem
# 373   ecosystem
# 407   ecosystem
# 416   ecosystem
# 418   ecosystem
# 422   ecosystem
# 424   ecosystem
# 428   ecosystem
# 432   ecosystem
# 436   ecosystem
# 440   ecosystem
# 444   ecosystem
# 446   ecosystem
# 456   ecosystem
# 458   ecosystem
# 461   ecosystem
# 2282  ecosystem
# ...         ...
# 2524  ecosystem
# 2525  ecosystem
# 2548  ecosystem
# 3042  ecosystem
# 3044  ecosystem
# 3051  ecosystem
# 3055  ecosystem
# 3058  ecosystem
# 3066  ecosystem
# 3071  ecosystem
# 3081  ecosystem
# 3083  ecosystem
# 3093  ecosystem
# 3095  ecosystem
# 3098  ecosystem
# 3103  ecosystem
# 3106  ecosystem
# 3109  ecosystem
# 3112  ecosystem
# 3115  ecosystem
# 3226  ecosystem
# 3230  ecosystem
# 3232  ecosystem
# 3236  ecosystem
# 3240  ecosystem
# 3244  ecosystem
# 3248  ecosystem
# 3282  ecosystem
# 3283  ecosystem
# 3284  ecosystem
#
# [85 rows x 10 columns]
